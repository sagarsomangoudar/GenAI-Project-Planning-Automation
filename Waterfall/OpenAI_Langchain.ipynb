# %%
# !pip install langchain langchain-openai
# Out:
# Requirement already satisfied: langchain in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (0.3.20)
# Requirement already satisfied: langchain-openai in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (0.3.44)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-openai) (1.66.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.8.2)
# Requirement already satisfied: sniffio in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: regex>=2022.1.18 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/denesh/Desktop/IIT-Chicago/Sem-3/SPM/VirtualLabs/Lab_4/venv_lab_4/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)

# %%
from langchain.agents import initialize_agent, AgentType
from langchain_openai import ChatOpenAI
from langchain_core.tools import Tool
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from constants import Constants

# %%
# Initialize the LLM
llm = ChatOpenAI(temperature=0.7, api_key=Constants.OPENAI_API_KEY)

# Define the search tool
def search_tool(query: str) -> str:
    """Tool to give respecive role features and responsibilities."""
    return f"Searching: {query}"

tools = [
    Tool(
        name="Search",
        func=search_tool,
        description="Tool to give respecive role features and responsibilities."
    )
]

# %%
task = "I want to develop, test and deploy a web and Artificial Intelligence based application for our retail Grocery store where my customers can browse, search an item, scan any item using barcode, add to cart, online payment, online-delivery, tracking of order and online feedback. You have to do the project in a Waterfall Model. " + "You have to give me the estimates from every phase. seperately. You take the sequence of conversations like this project manager, requirement engineer, system engineer, software engineer, testing engineer and documentation engineer. All the responses should be not more than 200 words"

# %% [markdown]
# --------------------------------------

# %%
# Define prompt templates for each role
customer_prompt = PromptTemplate(
    template="""
    You are a retail store manager. You know every corner of your retail store.
    You can transform your complex concepts into requirements for an IT company's Requirement Engineer.
    
    Initial requirement:
    I want to develop, test, and deploy a web and AI-based application for our retail grocery store where my customers can:
    - Browse items
    - Search for items
    - Scan items using barcode
    - Add items to cart
    - Make online payments
    - Arrange online delivery
    - Track orders
    - Provide online feedback
    
    Provide these requirements to the project manager.
    """
)

project_manager_prompt = PromptTemplate(
    template="""
    You are a project manager overseeing this project. Your role is to plan, execute, and complete the project.
    You define project scope, create timelines, allocate resources, and manage budgets.
    
    Received customer requirements:
    {customer_requirements}
    
    Now plan the project:
    - Define scope
    - Create timeline (Waterfall Model)
    - Allocate resources
    - Estimate budget
    - Provide the assumed number of days that this project my complete
    - create proper features and user stories.
    - Provide the plan to the requirement engineer.
    """
)

requirement_engineer_prompt = PromptTemplate(
    template="""
    You are a Requirement Engineer responsible for eliciting, analyzing, specifying, validating, and managing requirements.
    
    Received project plan:
    {project_plan}
    
    Now analyze and document detailed requirements:
    - Estimate total requirements pages (exact figure)
    - Estimate productivity rate (pages per hour) (exact figure)
    - List detailed feature
    
    Provide detailed requirements to the system engineer.
    """
)

design_system_engineer_prompt = PromptTemplate(
    template="""
    You are a System Engineer responsible for designing, integrating, and managing complex systems.
    
    Received detailed requirements:
    {detailed_requirements}
    
    Now create the system design:
    - Estimate total design document pages (exact figure)
    - Estimate productivity rate (pages per hour) (exact figure)
    - List design components (including database schema)
    - list all the entity relationships, databases and tables names, foreign and primary keys

    Provide system design to the software engineer.
    """
)

software_engineer_prompt = PromptTemplate(
    template="""
    You are a Software Engineer responsible for designing, developing, and maintaining software applications.
    
    Received system design:
    {system_design}
    
    Now develop the application:
    - Estimate total SLOCs (Source Lines of Code) (exact figure)
    - Estimate productivity rate (SLOCs per hour) (exact figure)
    - Specify technology stack
    - List implementation details
    - define which techology is better and why?
    - Do we need monolitic or microservice for this ?
    
    Provide development details to the testing engineer.
    """
)

testing_engineer_prompt = PromptTemplate(
    template="""
    You are a Testing Engineer responsible for ensuring software quality through testing.
    
    Received development details:
    {development_details}
    
    Now create and execute test cases:
    - Estimate total test cases (exact figure) 
    - Estimate productivity rate (test cases per hour) (exact figure)
    - Create test plan
    - per feature how many test cases (exact figure)
    
    Provide testing details to the documentation engineer.
    """
)

documentation_engineer_prompt = PromptTemplate(
    template="""
    You are a Documentation Engineer responsible for creating and maintaining technical documentation.
    
    Received testing details:
    {testing_details}
    
    Now create project documentation:
    - Estimate total documentation pages (exact figure)
    - Estimate productivity rate (pages per hour) (exact figure)
    - List documentation components
    - The documentation engineer is responsible for documenting and display all the estimates (Phase, Enginner-Name, Amount of work and productivity of work) (exact figure)

    Provide final documentation details.
    """
)

# %%
# # Initialize agents for each role
# customer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# project_manager_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# requirement_engineer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# design_system_engineer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# software_engineer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# testing_engineer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# documentation_engineer_agent = initialize_agent(
#     tools=tools,
#     llm=llm,
#     agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
#     verbose=True
# )

# %%
# Create LLM chains for each role
customer_chain = LLMChain(llm=llm, prompt=customer_prompt)
project_manager_chain = LLMChain(llm=llm, prompt=project_manager_prompt)
requirement_engineer_chain = LLMChain(llm=llm, prompt=requirement_engineer_prompt)
design_system_engineer_chain = LLMChain(llm=llm, prompt=design_system_engineer_prompt)
software_engineer_chain = LLMChain(llm=llm, prompt=software_engineer_prompt)
testing_engineer_chain = LLMChain(llm=llm, prompt=testing_engineer_prompt)
documentation_engineer_chain = LLMChain(llm=llm, prompt=documentation_engineer_prompt)

# %%
def run_waterfall_model():

    print("Starting Waterfall Model process...\n")
    # Customer phase
    print("Customer Speaks:")
    customer_requirements = customer_chain.run({"input": task})
    print(customer_requirements)
    print("\n") 
    
    # Project Manager phase
    print("Project Manager Speaks:")
    project_plan = project_manager_chain.run({"customer_requirements": customer_requirements})
    print(project_plan)
    print("\n")

    # Requirement Engineer phase
    print("Requirement Engineer Speaks:")
    detailed_requirements = requirement_engineer_chain.run({"project_plan": project_plan})
    print(detailed_requirements)
    print("\n")

    # Design System Engineer phase
    print("Design System Engineer Speaks:")
    system_design = design_system_engineer_chain.run({"detailed_requirements": detailed_requirements})
    print(system_design)
    print("\n")

    # Software Engineer phase
    print("Software Engineer Speaks:")
    development_details = software_engineer_chain.run({"system_design": system_design})
    print(development_details)
    print("\n")

    # Testing Engineer phase
    print("Testing Engineer Speaks:")
    testing_details = testing_engineer_chain.run({"development_details": development_details})
    print(testing_details)
    print("\n")

    # Documentation Engineer phase
    print("Documentation Engineer Speaks:")
    documentation_details = documentation_engineer_chain.run({"testing_details": testing_details})
    print(documentation_details)
    print("\n")

    print("Waterfall Model process completed.")


run_waterfall_model()
# Out:
# Starting Waterfall Model process...
#
# Customer Speaks:
# Requirements for the web and AI-based application development project:
#
# 1. The application should have a user-friendly interface that allows customers to easily browse items available in the store.
# 2. Customers should be able to search for specific items using a search bar functionality.
# 3. The application should have the capability to scan items using barcode technology for quick and accurate identification.
# 4. Customers should be able to add items to their virtual shopping cart for easy checkout.
# 5. The application should support online payment options for customers to make secure transactions.
# 6. Customers should be able to arrange for online delivery of their purchased items.
# 7. The application should provide order tracking functionality so customers can monitor the status of their orders.
# 8. Customers should be able to provide feedback on their shopping experience through an online feedback form or rating system.
# 9. The application should incorporate AI technology to provide personalized recommendations based on customer preferences and purchase history.
# 10. The application should be mobile-responsive to ensure a seamless shopping experience on different devices.
# 11. The application should have robust security measures in place to protect customer data and payment information.
# 12. The project timeline should include development, testing, and deployment phases to ensure a smooth and successful launch of the application.
#
#
# Project Manager Speaks:
# Scope:
# The scope of the project includes developing a web and AI-based application that meets the customer requirements outlined above. This includes creating a user-friendly interface, implementing search functionality, barcode scanning capability, virtual shopping cart, online payment options, online delivery, order tracking, feedback system, personalized recommendations, mobile responsiveness, and security measures.
#
# Timeline (Waterfall Model):
# 1. Requirements Gathering: 5 days
# 2. Design and Planning: 10 days
# 3. Development: 30 days
# 4. Testing: 10 days
# 5. Deployment: 5 days
#
# Total Estimated Project Duration: 60 days
#
# Resources:
# - Project Manager
# - Developers
# - Designers
# - Quality Assurance Testers
# - AI Specialists
# - Database Administrators
# - Security Experts
# - Customer Support Team
#
# Budget Estimate:
# The budget estimate for the project will depend on the rates of the resources involved and any additional costs such as software licenses or third-party services. A detailed budget breakdown will need to be created based on the specific requirements of the project.
#
# Features and User Stories:
# 1. As a customer, I want to easily browse items in the store.
# 2. As a customer, I want to search for specific items using a search bar.
# 3. As a customer, I want to scan items using barcode technology.
# 4. As a customer, I want to add items to my shopping cart for checkout.
# 5. As a customer, I want to make secure online payments.
# 6. As a customer, I want to arrange for online delivery of purchased items.
# 7. As a customer, I want to track the status of my orders.
# 8. As a customer, I want to provide feedback on my shopping experience.
# 9. As a customer, I want personalized recommendations based on my preferences.
# 10. As a customer, I want the application to be mobile-responsive.
# 11. As a customer, I want my data and payment information to be secure.
#
# Plan to Requirement Engineer:
# The project plan includes the scope, timeline, resource allocation, budget estimate, estimated project duration, features, and user stories. The requirement engineer will need to ensure that the development team understands and implements the customer requirements accurately. Regular communication and collaboration will be key to the successful completion of the project.
#
#
# Requirement Engineer Speaks:
# Estimating total requirements pages:
# Based on the scope and features outlined above, the total requirements pages are estimated to be around 20-30 pages.
#
# Estimating productivity rate (pages per hour):
# Assuming that the Requirement Engineer can dedicate 8 hours per day to documenting requirements, with an average of 5 pages per day, the productivity rate would be around 0.625 pages per hour.
#
# List of detailed features:
# 1. User-friendly interface design with easy navigation and intuitive layout
# 2. Implement search functionality with filters and sorting options
# 3. Barcode scanning capability integrated for quick item identification
# 4. Virtual shopping cart feature for adding and managing selected items
# 5. Online payment options with secure payment gateways
# 6. Online delivery scheduling and tracking system
# 7. Feedback system for customers to provide ratings and reviews
# 8. Personalized recommendations based on user preferences and purchase history
# 9. Mobile responsiveness for seamless access on various devices
# 10. Implementation of security measures to protect user data and payment information
#
# Providing detailed requirements to the system engineer:
# The Requirement Engineer will document the detailed requirements in a structured format, including functional and non-functional requirements, user stories, use cases, and system interactions. These requirements will be shared with the system engineer for further analysis, design, and development of the web and AI-based application. Regular communication and collaboration between the Requirement Engineer and the system engineer will be essential to ensure the accurate implementation of customer requirements.
#
#
# Design System Engineer Speaks:
# System Design:
#
# Estimating total design document pages:
# Based on the complexity of the features and requirements listed above, the total design document pages are estimated to be around 30-40 pages.
#
# Estimating productivity rate (pages per hour):
# Assuming that the System Engineer can dedicate 8 hours per day to designing, with an average of 5 pages per day, the productivity rate would be around 0.625 pages per hour.
#
# List of design components:
# 1. User Interface Design
# 2. Search Functionality Module
# 3. Barcode Scanning Integration
# 4. Shopping Cart Module
# 5. Payment Gateway Integration
# 6. Delivery Scheduling and Tracking Module
# 7. Feedback System Module
# 8. Personalized Recommendations Module
# 9. Mobile Responsiveness Module
# 10. Security Measures Implementation
#
# Database Schema:
# - User Table
# - Product Table
# - Cart Table
# - Order Table
# - Payment Table
# - Feedback Table
# - Recommendation Table
# - User Preference Table
# - Security Table
#
# Entity Relationships:
# - User can have multiple orders
# - Product can be in multiple carts
# - Order can have multiple products
# - Payment is linked to an order
# - Feedback is linked to a product
# - Recommendation is based on user preferences
#
# Provide system design to the software engineer for further development and implementation. Regular communication and collaboration between the System Engineer and the software engineer will be essential to ensure the successful execution of the system design.
#
#
# Software Engineer Speaks:
# To develop the application based on the provided system design, the following details can be considered:
#
# Estimate total SLOCs (Source Lines of Code):
# Based on the complexity of the system design and the list of design components, the total SLOCs can be estimated to be around 20,000-30,000 lines of code.
#
# Estimate productivity rate (SLOCs per hour):
# Assuming that the Software Engineer can dedicate 8 hours per day to development, with an average of 500 lines of code per day, the productivity rate would be around 62.5 SLOCs per hour.
#
# Specify technology stack:
# - Frontend: React.js for User Interface Design and Mobile Responsiveness
# - Backend: Node.js for Search Functionality, Shopping Cart, Delivery Scheduling, Feedback System, and Personalized Recommendations
# - Database: MySQL for Database Schema
#
# List implementation details:
# - Implement RESTful APIs for communication between frontend and backend
# - Implement JWT for authentication and authorization
# - Implement React Native for mobile responsiveness
# - Implement barcode scanning integration using a third-party library
# - Implement payment gateway integration using Stripe API
# - Implement security measures using encryption algorithms and HTTPS protocol
#
# Define which technology is better and why?
# Node.js and React.js are chosen for their scalability, performance, and ease of development. Node.js allows for non-blocking, event-driven architecture which is efficient for handling multiple requests, while React.js provides a component-based UI development approach for a dynamic and responsive user interface.
#
# Do we need monolithic or microservice for this?
# Considering the complexity and scalability requirements of the application, a microservices architecture would be more suitable. Microservices allow for independent development, deployment, and scaling of each component, leading to better flexibility and maintainability in the long run.
#
# Provide development details to the testing engineer:
# - Provide test cases for each module and integration testing scenarios
# - Ensure code coverage for all implemented features
# - Perform unit testing, integration testing, and end-to-end testing to ensure the application meets the requirements
# - Collaborate with the testing engineer to identify and resolve any bugs or issues during the testing phase
#
# Regular communication and collaboration between the Software Engineer, System Engineer, and Testing Engineer will be essential to ensure the successful development and testing of the application.
#
#
# Testing Engineer Speaks:
# Estimate total test cases:
# Based on the complexity of the application and the number of modules and integration points, the total test cases can be estimated to be around 500-700 test cases.
#
# Estimate productivity rate (test cases per hour):
# Assuming that the Testing Engineer can dedicate 8 hours per day to testing, with an average of 10-15 test cases per day, the productivity rate would be around 1.25-1.875 test cases per hour.
#
# Create test plan:
# 1. Unit Testing:
# - Test each individual component and function to ensure they work as expected.
# - Verify input validation, error handling, and boundary conditions.
# - Ensure code coverage for all implemented features.
#
# 2. Integration Testing:
# - Test the interaction between different modules and components.
# - Verify data flow and communication between frontend and backend.
# - Check for compatibility issues and ensure proper integration of third-party libraries.
#
# 3. End-to-End Testing:
# - Test the application as a whole to ensure all modules work together seamlessly.
# - Verify user flows, navigation, and functionality across different devices and browsers.
# - Perform regression testing to check for any unintended impacts on existing features.
#
# 4. Security Testing:
# - Test for vulnerabilities such as SQL injection, cross-site scripting, and authentication bypass.
# - Perform penetration testing to identify potential security risks and weaknesses.
# - Ensure encryption algorithms and security measures are implemented correctly.
#
# 5. Performance Testing:
# - Test the application under different load conditions to ensure it can handle user traffic.
# - Identify and optimize any bottlenecks or performance issues.
# - Monitor system resources and response times to ensure optimal performance.
#
# 6. User Acceptance Testing:
# - Collaborate with stakeholders and end-users to validate that the application meets their requirements.
# - Gather feedback and address any usability issues or concerns.
# - Ensure the application is user-friendly and meets the specified business goals.
#
# Regular communication and collaboration between the Testing Engineer, Software Engineer, and Documentation Engineer will be crucial to ensure the successful testing and documentation of the application.
#
#
# Documentation Engineer Speaks:
# Estimate total documentation pages:
# Based on the complexity of the application and the amount of testing involved, the total documentation pages can be estimated to be around 100-150 pages.
#
# Estimate productivity rate (pages per hour):
# Assuming that the Documentation Engineer can dedicate 8 hours per day to documentation, with an average of 5-7 pages per day, the productivity rate would be around 0.625-0.875 pages per hour.
#
# List documentation components:
# 1. User Manual: Detailed instructions on how to use the application, including step-by-step guides and screenshots.
# 2. Installation Guide: Instructions on how to install and set up the application, including system requirements and configuration steps.
# 3. API Documentation: Documentation on the application's APIs, including endpoints, parameters, and response formats.
# 4. Troubleshooting Guide: Common issues and solutions for users experiencing problems with the application.
# 5. Release Notes: Information on new features, bug fixes, and improvements in each version of the application.
# 6. Technical Specifications: Detailed technical information on the application architecture, design, and implementation.
# 7. Testing Documentation: Reports on test cases, results, and any issues encountered during testing.
#
# Final documentation details:
# The project documentation will consist of approximately 120 pages, with a productivity rate of 0.75 pages per hour. The documentation will cover all essential components, ensuring comprehensive information for users, developers, and stakeholders. Regular updates and collaboration with the Testing Engineer and Software Engineer will be crucial to maintain accurate and up-to-date documentation throughout the project lifecycle.
#
#
# Waterfall Model process completed.

# %% [markdown]
# ##### RESULTS
# ### Requirement Engineer:
# ##### Estimate total requirements pages: 20 - 30 pages.
# ##### Taking average : (20+30)/2 = 25 pages
# ##### Estimate productivity rate (pages per days): 5 pages per day,
# ##### Total - 5 days
#
# ### System Engineer:
# ##### Estimate total design document pages:  30-40 pages.
# ##### Taking average : (30+40)/2 = 35 pages
# ##### Estimate productivity rate (pages per days): 5 pages /day
# ##### Total - 7 days
#
# ### Software Engineer:
# ##### Estimate total SLOCs (Source Lines of Code):  20,000-30,000 SLOCs.
# ##### Taking average : (20,000+30,000)/2 = 25,000 SLOCs
# ##### Estimate productivity rate (SLOCs per days): 500 SLOCs/day
# ##### Total - 50 days
#
# ### Testing Engineer:
# ##### Estimated total test cases:  500-700  test cases
# ##### Taking average : (500+700)/2 = 600 test cases
# ##### Estimated productivity rate (test cases per days): 10-15 test cases per day
# ##### Taking average : (10+15 )/2 = 12.5 => 13 test cases /day
# ##### Total - 46.15 => 47 days
#
# ### Documentation Engineer :
# ##### Estimated total documentation pages:  100-150 pages
# ##### Taking average : (100+150)/2 = 125 pages
# ##### Estimated productivity rate (pages per days): 5-7 pages per hour,
# ##### Taking average : (5+7)/2 = 6 pages /day
# ##### total : 20.83 which is 21 days
#
# ### Total days approximately 130.
